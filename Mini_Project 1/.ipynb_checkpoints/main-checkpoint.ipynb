# %%
import glob
import pandas as pd

# %%
# create an empty list to hold the DataFrames
dfs = []

# loop through the csv files and load them into DataFrames
for filename in glob.glob('US_Census/*.csv'):
    df = pd.read_csv(filename, index_col=None, header=0)
#     df = df.drop("Unnamed: 0", axis=1)
    dfs.append(df)

# %%
# concatenate all of the DataFrames together into one
us_census = pd.concat(dfs, ignore_index=True)

us_census.to_csv("US_Census/data.csv", index=False)

# %%
df = pd.read_csv("US_Census/data.csv", index_col=None, header=0)
df = df.drop("Unnamed: 0.1", axis=1)
df
# Out:
#              State  TotalPop             Hispanic                White  \
# 0          Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           Alaska    733375   5.909580838323351%  60.910179640718574%
# 2          Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3         Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4       California  38421464  37.291874687968054%   40.21578881677474%
# ..             ...       ...                  ...                  ...
# 175        Vermont    626604  1.6092896174863391%   93.98306010928961%
# 176       Virginia   8256630     8.0110164981373%  63.271048430015945%
# 177     Washington   6985464  11.140968858131506%   72.03840830449816%
# 178  West Virginia   1851420   1.290909090909089%   92.17623966942146%
# 179      Wisconsin   5742117   6.683333333333334%   79.86400862068966%
#
#                    Black                Native                Asian  \
# 0     31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1    2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2    3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3    18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4     5.677396405391911%  0.40529206190713685%  13.052234148776776%
# ..                   ...                   ...                  ...
# 175  0.9808743169398909%    0.301639344262295%  1.2387978142076501%
# 176   20.17599787120807%  0.21245343267695582%   5.455242150079845%
# 177   3.384429065743947%   1.4107266435986163%   7.022006920415224%
# 178  3.6628099173553723%  0.15268595041322316%  0.6824380165289253%
# 179   8.195186781609202%   0.9536637931034483%   2.404238505747124%
#
#                    Pacific               Income            GenderPop
# 0     0.03435374149659865%   $43296.35860306644    2341093M_2489527F
# 1      1.0586826347305378%   $70354.74390243902      384160M_349215F
# 2     0.16763157894736833%   $54207.82095490716    3299088M_3342840F
# 3     0.14686131386861315%   $41935.63396778917    1451913M_1506295F
# 4     0.35141038442336353%   $67264.78230266465  19087135M_19334329F
# ..                     ...                  ...                  ...
# 175   0.03060109289617486%   $55602.96721311475      308573M_318031F
# 176   0.06471527408195847%   $72866.01341201717    4060948M_4195682F
# 177     0.609896193771627%   $64493.76768377254    3487725M_3497739F
# 178   0.02644628099173554%   $41437.11157024794      913631M_937789F
# 179  0.020833333333333332%  $53898.889208633096    2851385M_2890732F
#
# [180 rows x 10 columns]

# %%
# inspect the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      180 non-null    object
#  1   TotalPop   180 non-null    int64
#  2   Hispanic   180 non-null    object
#  3   White      180 non-null    object
#  4   Black      180 non-null    object
#  5   Native     180 non-null    object
#  6   Asian      180 non-null    object
#  7   Pacific    165 non-null    object
#  8   Income     180 non-null    object
#  9   GenderPop  180 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 14.2+ KB
